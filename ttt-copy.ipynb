# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open(r"C:\Users\tatsuya\PycharmProjects\strn\1703180128.7975607.result.json",encoding="utf-8",mode="r") as f:
    d = json.load(f)

# %%
df = pd.DataFrame(d["indicators"])
# df = df.iloc[:450]

# %%
fig,ax = plt.subplots(4,1,sharex=True)

df["train_first_loss"].abs().plot(ax=ax[2],)
df["train_second_loss"].plot(ax=ax[3],)

df["train_est_loss"].plot(ax=ax[0])
# df[""].plot(ax=ax[0])

df["simple_testLoss"].plot(ax=ax[1])

fig.legend()

# %% [markdown]
# オーバーフィッティングがtraining第二項の増加で検出できている
