# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open(r"C:\Users\tatsuya\PycharmProjects\strn\1702890406.037857.result.json",encoding="utf-8",mode="r") as f:
    d = json.load(f)

# %%
df = pd.DataFrame(d["indicators"])

# %%
fig,ax = plt.subplots(2,1,sharex=True)
df["train_first_loss"].plot(ax=ax[0])
df["simple_testLoss"].plot(ax=ax[1])
# Out:
# <Axes: >
