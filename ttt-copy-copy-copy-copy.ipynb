# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open(r"1703540445.245305.result.json",encoding="utf-8",mode="r") as f:
    d = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open(r"1703540445.245305.result.json",encoding="utf-8",mode="r") as f:
#       2     d = json.load(f)
#
# File c:\Users\tatsuya\PycharmProjects\strn\venv\lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '1703540445.245305.result.json'

# %%
df = pd.DataFrame(d["indicators"])
# df = df.iloc[300:]

# %%
fig,ax = plt.subplots(5,1,sharex=True)

df["train_est_loss"].plot(ax=ax[0])
df["simple_testLoss"].plot(ax=ax[1])
df["weighted_testLoss"].plot(ax=ax[1])
# df["new_weighted_testLoss"].plot(ax=ax[1])
df["train_first_loss"].plot(ax=ax[2],)
df["train_second_loss"].plot(ax=ax[3],)

# df[""].plot(ax=ax[0])

(df["train_first_loss"] + df["train_second_loss"]).plot(ax=ax[4])
fig.legend()
